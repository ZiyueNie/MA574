# %% [markdown]
# <a href="https://colab.research.google.com/github/ZiyueNie/MA574/blob/master/src/leverage.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/ZiyueNie/MA574
# Out:
# Cloning into 'MA574'...
# remote: Enumerating objects: 5, done.
# remote: Counting objects: 100% (5/5), done.
# remote: Compressing objects: 100% (5/5), done.
# remote: Total 110 (delta 0), reused 0 (delta 0), pack-reused 105
# Receiving objects: 100% (110/110), 101.15 KiB | 14.45 MiB/s, done.
# Resolving deltas: 100% (5/5), done.

# %%
cd MA574/data/holdingperiod/
# Out:
# /content/MA574/data/holdingperiod/MA574/data/holdingperiod

# %%
import csv
import numpy
import matplotlib.pyplot as plt
import numpy as np

# %%
names=['1030','1031','1101','1104','1105','1106','1107','1108','1111','1112','1113','1114','1115','1118','1119','1120','1121','1122','1125','1126','1127','1129','1202','1203','1204','1205','1206']
def getData():
    L=[]
    S=[]
    for name in names:
        with open(name+'.csv') as file:
            reader=csv.reader(file)
            rows=[row[0] for row in reader]
            Rows=np.array([row for row in rows])
            Rows[0]=(Rows[0])[1:]
            leverage=np.array([float(Rows[i]) for i in range(len(Rows))])
            l=(sum(leverage[leverage>0])+abs(sum(leverage[leverage<0])))/(sum(leverage[leverage>0])+sum(leverage[leverage<0]))
            s=sum(leverage)
            L.append(l)
            S.append(s)
            
    return L,S

# %%
Rows,s=getData()
plt.plot([i for i in range(27)],Rows,label='Daily leverage ratio')
plt.xlabel('names')
plt.legend()
plt.show()

# %%
Rows,s=getData()
plt.plot(names,Rows,label='Daily leverage ratio', color = 'r')
plt.plot(names,np.array(s)/100000,label='Daily Market Value',color = 'b')
plt.xticks(rotation = 90)
plt.legend()
plt.show()
#plt.xlabel('names')
#plt.xticks(rotation = 90)
#plt.legend()
#plt.show()

# %%
Rows,s=getData()
plt.plot([i for i in range(27)],s,label='Daily Market Value')
plt.legend()
plt.show()
